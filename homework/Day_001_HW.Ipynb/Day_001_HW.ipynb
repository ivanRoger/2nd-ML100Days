# %% [markdown]
# ### 作業1：
#
# ### 資料集：Los Angeles Metro Bike Share Trip Data
# ### [kaggle](https://www.kaggle.com/cityofLA/los-angeles-metro-bike-share-trip-data)
#
# ### 1. 你選的這組資料為何重要
# 近年來共享經濟成為日常生活中日益重要的新興經濟模式，但在此種經濟模式的背後往往會引發資源浪費的問題。透過洛杉磯政府所提供的共享單車相關資料，能進一步探討不同的騎乘旅客在騎乘上的特殊偏好，並可將相關資訊做為未來政府劃設共享單車之選址與設置數量的參考依據，極大化每一個單車站的使用效率，減少資源浪費。
#
# ### 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 此份資料由洛杉磯市的公開資料平台所提供。
# 以每位旅客初次騎乘單車時所註冊的資料以及借車還車感應卡片的時間來作為資料蒐集的來源。
#
# ### 3. 蒐集而來的資料型態為何
# 為結構化資料。
# 欄位分別有：
# Start Time、End Time（Date）；Trip ID、Duration、Starting Station ID、Starting Station Latitude、Starting Station Longitude、Ending Station ID、Ending Station Latitude、Ending Station Longitude、Bike ID、Plan Duration（Numeric）；Trip Route Category、Passholder Type、Starting Lat-Long、Ending Lat-Long（String）。
#
# ### 4. 這組資料想解決的問題如何評估
# 可利用多元線性迴歸模型來預測在何種情況下會有最多的單車使用率。
#
#
# ### 作業2：
#
# ### 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# ### 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 作為一個自由載客車隊，勢必要四處奔走以回應顧客的叫車需求，甚至尋找到更多的潛在客戶。而來回奔走所花費的時間則成為看不見的沉默成本且效率不彰。為提升效率與業績，必須更精準的分辨出真正會搭乘與不會搭乘的顧客，並預測各地區位置之顧客需求量，以更有效的分配車隊在各地區位置的數量，極小化駕駛花費在來回奔波的時間。
#
# ### 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 可先發展出一套叫車app（如台灣大車隊、Uber），讓用戶在註冊時填寫相關資料，如此一來用戶在每一次叫車時便可留下相關紀錄（如叫車時間、地點、下車位置、搭乘人數、搭乘時間等）。
#
# ### 3. 蒐集而來的資料型態為何
# 為方便分析，應會進行結構化資料的蒐集，其中包含連續型和離散型變數資料。
#
# ### 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 〈法一〉：
# 利用分類方法區分出”會搭乘”與”不會搭乘”之客戶，再透過混沌矩陣檢驗模型之預測準確度。利用得出之分析結果作為分配各地理區車隊數量的依據。
#
# 〈法二〉：
# 利用多元迴歸模型找出各個自變數對於依變數的影響程度，再利用得出之分析結果作為分配各地理區車隊數量的依據。
#
#
#
# ## 練習時間~
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y,yp):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse: MSE
    """
    mse = MSE = sum((y-yp)**2)/len(y)            
    return mse

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 282.260
# The Mean absolute error is 13.491
